# %%
import os
import numpy as np
import threading as thr
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Conv2D, BatchNormalization, MaxPool2D, Dense, Flatten, InputLayer, Activation, Dropout
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_curve, auc
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping

# %%
import matlab.engine
eng = matlab.engine.start_matlab()

# %%
mammo_o = []
mammo_f = []
label = []
project_folder = "C:/Users/utente/Documents/CMEPDA_final_project/dataset/"
os.chdir(project_folder)
l = os.listdir()

# %%
def create_dataset(ls, o_img, f_img, lbl):
    for l in ls:
        if "_1_resized.pgm" in l:
            mo, mf = eng.dataset_filtered(eng.char(os.path.join(project_folder,l)), nargout = 2)
            o_img.append(mo)
            f_img.append(mf)
            lbl.append(1)
        elif "_2_resized.pgm" in l:
            mo, mf = eng.dataset_filtered(eng.char(os.path.join(project_folder,l)), nargout = 2)
            o_img.append(mo)
            f_img.append(mf)
            lbl.append(0)

# %%
os.chdir("C:/Users/utente/Documents/CMEPDA_final_project/")
threads = []
chunk = 49
print(chunk)/
for i in range(6):
    t = thr.Thread(target = create_dataset, args = (l[i*chunk : (i+1)*chunk], mammo_o, mammo_f, label))
    threads.append(t)
    t.start()

for i in threads:
    i.join()
# Out:
# 49

# %%
eng.quit()

# %%
mammo_o = np.asarray(mammo_o, dtype = 'float32')/255.
mammo_f = np.asarray(mammo_f, dtype = 'float32')/255.
label = np.asarray(label)

# %%
mammo_o_4d = np.reshape(mammo_o, (147, 125, 125, 1))
print(mammo_o_4d.shape)
mammo_f_4d = np.reshape(mammo_f, (147, 64, 64, 1))
print(mammo_f_4d.shape)
# Out:
# (147, 125, 125, 1)
# (147, 64, 64, 1)

# %%
def cnn_o(shape=(125, 125, 1)):
    model = Sequential([
        
        Conv2D(5, (5,5), padding = 'same', input_shape = shape),
        BatchNormalization(),
        Activation('relu'),
        
        MaxPool2D((6,6), strides = 2),
        #Dropout(0.2),
        
        
        Conv2D(6, (5,5), padding = 'same'),
        BatchNormalization(),
        Activation('relu'),
        
        MaxPool2D((6,6), strides = 2),
        #Dropout(0.1),
        
        
        Conv2D(10, (5,5), padding = 'same'),
        BatchNormalization(),
        Activation('relu'),
        
        MaxPool2D((6,6), strides = 2),
        #Dropout(0.1),
        
        Flatten(),
        
        Dense(10, activation = 'relu'),
        #Dropout(0.1),
        Dense(1, activation = 'sigmoid')        
        
    ])
    
    return model

# %%
model_o = cnn_o()
model_o.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_3 (Conv2D)           (None, 125, 125, 5)       130
#
#  batch_normalization_3 (Batc  (None, 125, 125, 5)      20
#  hNormalization)
#
#  activation_3 (Activation)   (None, 125, 125, 5)       0
#
#  max_pooling2d_3 (MaxPooling  (None, 60, 60, 5)        0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 60, 60, 6)         756
#
#  batch_normalization_4 (Batc  (None, 60, 60, 6)        24
#  hNormalization)
#
#  activation_4 (Activation)   (None, 60, 60, 6)         0
#
#  max_pooling2d_4 (MaxPooling  (None, 28, 28, 6)        0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 28, 28, 10)        1510
#
#  batch_normalization_5 (Batc  (None, 28, 28, 10)       40
#  hNormalization)
#
#  activation_5 (Activation)   (None, 28, 28, 10)        0
#
#  max_pooling2d_5 (MaxPooling  (None, 12, 12, 10)       0
#  2D)
#
#  flatten_1 (Flatten)         (None, 1440)              0
#
#  dense_2 (Dense)             (None, 10)                14410
#
#  dense_3 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 16,901
# Trainable params: 16,859
# Non-trainable params: 42
# _________________________________________________________________

# %%
from tensorflow.keras.optimizers import SGD
learning_rate = 0.001
model_o.compile(optimizer = SGD(learning_rate, momentum = 0.9), loss = 'binary_crossentropy', metrics = ['accuracy'])
#model_f.compile(optimizer = SGD(learning_rate, momentum = 0.9), loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
from keras.preprocessing.image import ImageDataGenerator

aug = ImageDataGenerator(
                rotation_range = 90,
                horizontal_flip = True,
                vertical_flip = True,
                validation_split = 0.21)

Xaug_train_o = aug.flow(X_slice_o, Y_slice_o, batch_size = 30, subset = 'training')
Xaug_val_o = aug.flow(X_slice_o, Y_slice_o, batch_size = 30, subset = 'validation')

Xaug_train_f = aug.flow(X_slice_f, Y_slice_f, subset = 'training')
Xaug_val_f = aug.flow(X_slice_f, Y_slice_f, subset = 'validation')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 9
#       1 from keras.preprocessing.image import ImageDataGenerator
#       3 aug = ImageDataGenerator(
#       4                 rotation_range = 90,
#       5                 horizontal_flip = True,
#       6                 vertical_flip = True,
#       7                 validation_split = 0.21)
# ----> 9 Xaug_train_o = aug.flow(X_slice_o, Y_slice_o, batch_size = 30, subset = 'training')
#      10 Xaug_val_o = aug.flow(X_slice_o, Y_slice_o, batch_size = 30, subset = 'validation')
#      12 Xaug_train_f = aug.flow(X_slice_f, Y_slice_f, subset = 'training')
#
# NameError: name 'X_slice_o' is not defined

# %%
reduce_on_plateau = ReduceLROnPlateau(
    monitor="val_loss",
    factor=0.1,
    patience=10,
    verbose=0,
    mode="auto",
    min_delta=0.0001,
    cooldown=0,
    min_lr=0)

# %%
X_train_o, X_val_o, Y_train_o, Y_val_o = train_test_split(mammo_o_4d, label, test_size = 0.2)
batch_size = 49
traino = model_o.fit(X_train_o, Y_train_o,
                            batch_size = batch_size,
                            epochs = 200,
                            #steps_per_epoch = np.shape(X_train_o)[0]/batch_size,
                            verbose=1,
                            validation_data=(X_val_o, Y_val_o), callbacks = [reduce_on_plateau])#,
                            #validation_steps=np.shape(X_val_o)[0]/batch_size,
                            #callbacks=[checkpoint,reduce_on_plateau])
# Out:
# Epoch 1/200
# 3/3 [==============================] - 3s 715ms/step - loss: 0.8017 - accuracy: 0.5299 - val_loss: 0.6854 - val_accuracy: 0.6333 - lr: 0.0010
# Epoch 2/200
# 3/3 [==============================] - 2s 575ms/step - loss: 0.6695 - accuracy: 0.7009 - val_loss: 0.6770 - val_accuracy: 0.7667 - lr: 0.0010
# Epoch 3/200
# 3/3 [==============================] - 2s 570ms/step - loss: 0.5436 - accuracy: 0.7265 - val_loss: 0.6722 - val_accuracy: 0.8333 - lr: 0.0010
# Epoch 4/200
# 3/3 [==============================] - 2s 575ms/step - loss: 0.5789 - accuracy: 0.6923 - val_loss: 0.6723 - val_accuracy: 0.6667 - lr: 0.0010
# Epoch 5/200
# 3/3 [==============================] - 2s 569ms/step - loss: 0.4993 - accuracy: 0.7778 - val_loss: 0.6748 - val_accuracy: 0.5667 - lr: 0.0010
# Epoch 6/200
# 3/3 [==============================] - 2s 570ms/step - loss: 0.4972 - accuracy: 0.7863 - val_loss: 0.6777 - val_accuracy: 0.4667 - lr: 0.0010
# Epoch 7/200
# 3/3 [==============================] - 2s 649ms/step - loss: 0.4627 - accuracy: 0.7863 - val_loss: 0.6795 - val_accuracy: 0.4667 - lr: 0.0010
# Epoch 8/200
# 3/3 [==============================] - 2s 601ms/step - loss: 0.4827 - accuracy: 0.7692 - val_loss: 0.6849 - val_accuracy: 0.5000 - lr: 0.0010
# Epoch 9/200
# 3/3 [==============================] - 2s 602ms/step - loss: 0.4160 - accuracy: 0.8034 - val_loss: 0.6814 - val_accuracy: 0.5000 - lr: 0.0010
# Epoch 10/200
# 3/3 [==============================] - 2s 577ms/step - loss: 0.3980 - accuracy: 0.8547 - val_loss: 0.6788 - val_accuracy: 0.5667 - lr: 0.0010
# Epoch 11/200
# 3/3 [==============================] - 2s 613ms/step - loss: 0.3905 - accuracy: 0.8205 - val_loss: 0.6795 - val_accuracy: 0.5333 - lr: 0.0010
# Epoch 12/200
# 3/3 [==============================] - 2s 586ms/step - loss: 0.3783 - accuracy: 0.8291 - val_loss: 0.6820 - val_accuracy: 0.5000 - lr: 0.0010
# Epoch 13/200
# 3/3 [==============================] - 2s 610ms/step - loss: 0.3635 - accuracy: 0.8547 - val_loss: 0.6817 - val_accuracy: 0.5000 - lr: 0.0010
# Epoch 14/200
# 3/3 [==============================] - 2s 594ms/step - loss: 0.3560 - accuracy: 0.8462 - val_loss: 0.6794 - val_accuracy: 0.5333 - lr: 1.0000e-04
# Epoch 15/200
# 3/3 [==============================] - 2s 594ms/step - loss: 0.3854 - accuracy: 0.7949 - val_loss: 0.6782 - val_accuracy: 0.5333 - lr: 1.0000e-04
# Epoch 16/200
# 3/3 [==============================] - 2s 579ms/step - loss: 0.4140 - accuracy: 0.8120 - val_loss: 0.6778 - val_accuracy: 0.5333 - lr: 1.0000e-04
# Epoch 17/200
# 3/3 [==============================] - 2s 602ms/step - loss: 0.3893 - accuracy: 0.8376 - val_loss: 0.6784 - val_accuracy: 0.5333 - lr: 1.0000e-04
# Epoch 18/200
# 3/3 [==============================] - 2s 697ms/step - loss: 0.3556 - accuracy: 0.8462 - val_loss: 0.6805 - val_accuracy: 0.5000 - lr: 1.0000e-04
# Epoch 19/200
# 3/3 [==============================] - 2s 584ms/step - loss: 0
- val_accuracy: 0.6000 - lr: 1.0000e-21
# Epoch 193/200
# 3/3 [==============================] - 2s 652ms/step - loss: 0.2900 - accuracy: 0.8974 - val_loss: 0.6645 - val_accuracy: 0.6000 - lr: 1.0000e-21
# Epoch 194/200
# 3/3 [==============================] - 2s 610ms/step - loss: 0.2896 - accuracy: 0.8889 - val_loss: 0.6628 - val_accuracy: 0.6000 - lr: 1.0000e-21
# Epoch 195/200
# 3/3 [==============================] - 2s 608ms/step - loss: 0.2897 - accuracy: 0.8974 - val_loss: 0.6616 - val_accuracy: 0.6000 - lr: 1.0000e-21
# Epoch 196/200
# 3/3 [==============================] - 2s 669ms/step - loss: 0.2994 - accuracy: 0.8803 - val_loss: 0.6600 - val_accuracy: 0.6000 - lr: 1.0000e-21
# Epoch 197/200
# 3/3 [==============================] - 2s 621ms/step - loss: 0.2903 - accuracy: 0.8889 - val_loss: 0.6589 - val_accuracy: 0.6000 - lr: 1.0000e-21
# Epoch 198/200
# 3/3 [==============================] - 2s 591ms/step - loss: 0.3024 - accuracy: 0.8889 - val_loss: 0.6576 - val_accuracy: 0.6000 - lr: 1.0000e-21
# Epoch 199/200
# 3/3 [==============================] - 2s 561ms/step - loss: 0.2992 - accuracy: 0.8803 - val_loss: 0.6555 - val_accuracy: 0.6000 - lr: 1.0000e-21
# Epoch 200/200
# 3/3 [==============================] - 2s 619ms/step - loss: 0.2919 - accuracy: 0.8803 - val_loss: 0.6540 - val_accuracy: 0.6000 - lr: 1.0000e-21

# %%
acc = traino.history['accuracy']
val_acc = traino.history['val_accuracy']
loss = traino.history['loss']
val_loss = traino.history['val_loss']
    
epochs_range = range(1, len(acc)+1)
    #Train and validation accuracy 
plt.figure(figsize=(15, 15))
plt.subplot(2, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')
    #Train and validation loss 
plt.subplot(2, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
_, val_acc = model_o.evaluate(X_val_o, Y_val_o, verbose=0)
print('Validation accuracy: %.3f' % (val_acc))
    
    
preds = model_o.predict(X_val_o, verbose=1)

    #Compute Receiver operating characteristic (ROC)
fpr, tpr, _ = roc_curve(Y_val_o, preds)

roc_auc = auc(fpr, tpr)
   #Plot of a ROC curve
plt.figure()
lw = 2
plt.plot(fpr, tpr, color='darkorange', lw=lw, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic example')
plt.legend(loc="lower right")
plt.show()
# Out:
# Validation accuracy: 0.600
# 1/1 [==============================] - 0s 301ms/step

# %%
#CROSS-VALIDATION with ORIGINAL DATA (X_slice_o)

A = []
V_A = []
L = []
V_L = []
ROC = []

for i in range(3):
    X_train_o, X_val_o, Y_train_o, Y_val_o = train_test_split(mammo_o_4d, label, test_size = 0.168, random_state = 40)
    traino = model_o.fit(X_train_o, Y_train_o,
                            batch_size = 49,
                            epochs = 200,
                            verbose=1,
                            validation_data=(X_val_o, Y_val_o),
                            callbacks=[checkpoint,reduce_on_plateau])
    
    acc = traino.history['accuracy']
    val_acc = traino.history['val_accuracy']
    loss = traino.history['loss']
    val_loss = traino.history['val_loss']
    
    A.append(acc)
    V_A.append(val_acc)
    L.append(loss)
    V_L.append(val_loss)
    
    epochs_range = range(1, len(acc)+1)
    #Train and validation accuracy 
    plt.figure(figsize=(15, 15))
    plt.subplot(2, 2, 1)
    plt.plot(epochs_range, acc, label='Training Accuracy')
    plt.plot(epochs_range, val_acc, label='Validation Accuracy')
    plt.legend(loc='lower right')
    plt.title('Training and Validation Accuracy')
    #Train and validation loss 
    plt.subplot(2, 2, 2)
    plt.plot(epochs_range, loss, label='Training Loss')
    plt.plot(epochs_range, val_loss, label='Validation Loss')
    plt.legend(loc='upper right')
    plt.title('Training and Validation Loss')
    plt.show()
    
    _, val_acc = model_o.evaluate(X_val_o, Y_val_o, verbose=0)
    print('Validation accuracy: %.3f' % (val_acc))
    
    
    preds = model_o.predict(X_val_o, verbose=1)

    #Compute Receiver operating characteristic (ROC)
    fpr, tpr, _ = roc_curve(Y_val_o, preds)

    roc_auc = auc(fpr, tpr)
    ROC.append(roc_auc)
    #Plot of a ROC curve
    plt.figure()
    lw = 2
    plt.plot(fpr, tpr, color='darkorange', lw=lw, label='ROC curve (area = %0.2f)' % roc_auc)
    plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver operating characteristic example')
    plt.legend(loc="lower right")
    plt.show()

# %%
media = np.mean(ROC)
std = np.std(ROC)
print(media)
print(std)
