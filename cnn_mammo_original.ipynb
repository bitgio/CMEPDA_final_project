# %%
import os
import numpy as np
import threading as thr
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Conv2D, BatchNormalization, MaxPool2D, Dense, Flatten, InputLayer, Activation, Dropout
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_curve, auc
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping

# %%
import matlab.engine
eng = matlab.engine.start_matlab()

# %%
mammo_o = []
mammo_f = []
label = []
project_folder = "C:/Users/anapascual/cmepda/progetto/dataset/"
os.chdir(project_folder)
l = os.listdir()

# %%
def create_dataset(ls, o_img, f_img, lbl):
    """ Function calling the Matlab file in order to filter the images
    
    ARGUMENTS
    ---------
    ls : list
         Chunk of files' directory.
         
    
    Return:
        Dataset with all images filtered.
    """
        if "_1_resized.pgm" in l:
            mo, mf = eng.dataset_filtered(eng.char(os.path.join(project_folder,l)), nargout = 2)
            o_img.append(mo)
            f_img.append(mf)
            lbl.append(1)
        elif "_2_resized.pgm" in l:
            mo, mf = eng.dataset_filtered(eng.char(os.path.join(project_folder,l)), nargout = 2)
            o_img.append(mo)
            f_img.append(mf)
            lbl.append(0)
# Out:
#   Cell In[1], line 13
#     if "_1_resized.pgm" in l:
#     ^
# IndentationError: unexpected indent

# %%
os.chdir("C:/Users/anapascual/cmepda/progetto/")
threads = []
chunk = 49
print(chunk)
for i in range(6):
    t = thr.Thread(target = create_dataset, args = (l[i*chunk : (i+1)*chunk], mammo_o, mammo_f, label))
    threads.append(t)
    t.start()

for i in threads:
    i.join()
# Out:
# 49

# %%
eng.quit()

# %%
mammo_o = np.asarray(mammo_o, dtype = 'float32')/255.
mammo_f = np.asarray(mammo_f, dtype = 'float32')/255.
label = np.asarray(label)

# %%
mammo_o_4d = np.reshape(mammo_o, (147, 125, 125, 1))
print(mammo_o_4d.shape)
mammo_f_4d = np.reshape(mammo_f, (147, 64, 64, 1))
print(mammo_f_4d.shape)
# Out:
# (147, 125, 125, 1)
# (147, 64, 64, 1)

# %%
def cnn_o(shape=(125, 125, 1)):
    model = Sequential([
        
        Conv2D(5, (5,5), padding = 'same', input_shape = shape),
        BatchNormalization(),
        Activation('relu'),
        
        MaxPool2D((6,6), strides = 2),
        #Dropout(0.2),
        
        
        Conv2D(6, (5,5), padding = 'same'),
        BatchNormalization(),
        Activation('relu'),
        
        MaxPool2D((6,6), strides = 2),
        #Dropout(0.1),
        
        
        Conv2D(10, (5,5), padding = 'same'),
        BatchNormalization(),
        Activation('relu'),
        
        MaxPool2D((6,6), strides = 2),
        #Dropout(0.1),
        
        Flatten(),
        
        Dense(10, activation = 'relu'),
        #Dropout(0.1),
        Dense(1, activation = 'sigmoid')        
        
    ])
    
    return model

# %%
model_o = cnn_o()
model_o.summary()
# Out:
# Model: "sequential_14"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_42 (Conv2D)          (None, 125, 125, 5)       130
#
#  batch_normalization_42 (Bat  (None, 125, 125, 5)      20
#  chNormalization)
#
#  activation_42 (Activation)  (None, 125, 125, 5)       0
#
#  max_pooling2d_42 (MaxPoolin  (None, 60, 60, 5)        0
#  g2D)
#
#  conv2d_43 (Conv2D)          (None, 60, 60, 6)         756
#
#  batch_normalization_43 (Bat  (None, 60, 60, 6)        24
#  chNormalization)
#
#  activation_43 (Activation)  (None, 60, 60, 6)         0
#
#  max_pooling2d_43 (MaxPoolin  (None, 28, 28, 6)        0
#  g2D)
#
#  conv2d_44 (Conv2D)          (None, 28, 28, 10)        1510
#
#  batch_normalization_44 (Bat  (None, 28, 28, 10)       40
#  chNormalization)
#
#  activation_44 (Activation)  (None, 28, 28, 10)        0
#
#  max_pooling2d_44 (MaxPoolin  (None, 12, 12, 10)       0
#  g2D)
#
#  flatten_14 (Flatten)        (None, 1440)              0
#
#  dense_28 (Dense)            (None, 10)                14410
#
#  dense_29 (Dense)            (None, 1)                 11
#
# =================================================================
# Total params: 16,901
# Trainable params: 16,859
# Non-trainable params: 42
# _________________________________________________________________

# %%
from tensorflow.keras.optimizers import SGD
learning_rate = 0.001
model_o.compile(optimizer = SGD(learning_rate, momentum = 0.9), loss = 'binary_crossentropy', metrics = ['accuracy'])
#model_f.compile(optimizer = SGD(learning_rate, momentum = 0.9), loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
from keras.preprocessing.image import ImageDataGenerator

aug = ImageDataGenerator(
                rotation_range = 90,
                horizontal_flip = True,
                vertical_flip = True,
                validation_split = 0.21)

Xaug_train_o = aug.flow(X_slice_o, Y_slice_o, batch_size = 30, subset = 'training')
Xaug_val_o = aug.flow(X_slice_o, Y_slice_o, batch_size = 30, subset = 'validation')

Xaug_train_f = aug.flow(X_slice_f, Y_slice_f, subset = 'training')
Xaug_val_f = aug.flow(X_slice_f, Y_slice_f, subset = 'validation')

# %%
reduce_on_plateau = ReduceLROnPlateau(
    monitor="val_loss",
    factor=0.1,
    patience=10,
    verbose=0,
    mode="auto",
    min_delta=0.0001,
    cooldown=0,
    min_lr=0)

# %%
X_train_o, X_val_o, Y_train_o, Y_val_o = train_test_split(mammo_o_4d, label, test_size = 0.2)
batch_size = 49
traino = model_o.fit(X_train_o, Y_train_o,
                            batch_size = batch_size,
                            epochs = 200,
                            #steps_per_epoch = np.shape(X_train_o)[0]/batch_size,
                            verbose=1,
                            validation_data=(X_val_o, Y_val_o), callbacks = [reduce_on_plateau])#,
                            #validation_steps=np.shape(X_val_o)[0]/batch_size,
                            #callbacks=[checkpoint,reduce_on_plateau])
# Out:
# Epoch 1/200
# 3/3 [==============================] - 1s 212ms/step - loss: 0.1641 - accuracy: 0.9658 - val_loss: 0.1965 - val_accuracy: 0.9333 - lr: 1.0000e-10
# Epoch 2/200
# 3/3 [==============================] - 1s 195ms/step - loss: 0.1674 - accuracy: 0.9573 - val_loss: 0.1956 - val_accuracy: 0.9333 - lr: 1.0000e-10
# Epoch 3/200
# 3/3 [==============================] - 1s 216ms/step - loss: 0.1622 - accuracy: 0.9573 - val_loss: 0.1948 - val_accuracy: 0.9333 - lr: 1.0000e-10
# Epoch 4/200
# 3/3 [==============================] - 1s 209ms/step - loss: 0.1662 - accuracy: 0.9658 - val_loss: 0.1941 - val_accuracy: 0.9000 - lr: 1.0000e-10
# Epoch 5/200
# 3/3 [==============================] - 1s 183ms/step - loss: 0.1666 - accuracy: 0.9658 - val_loss: 0.1935 - val_accuracy: 0.9000 - lr: 1.0000e-10
# Epoch 6/200
# 3/3 [==============================] - 1s 191ms/step - loss: 0.1626 - accuracy: 0.9658 - val_loss: 0.1928 - val_accuracy: 0.9000 - lr: 1.0000e-10
# Epoch 7/200
# 3/3 [==============================] - 1s 187ms/step - loss: 0.1602 - accuracy: 0.9658 - val_loss: 0.1919 - val_accuracy: 0.9000 - lr: 1.0000e-10
# Epoch 8/200
# 3/3 [==============================] - 1s 185ms/step - loss: 0.1714 - accuracy: 0.9573 - val_loss: 0.1913 - val_accuracy: 0.9000 - lr: 1.0000e-10
# Epoch 9/200
# 3/3 [==============================] - 0s 150ms/step - loss: 0.1677 - accuracy: 0.9487 - val_loss: 0.1907 - val_accuracy: 0.9000 - lr: 1.0000e-10
# Epoch 10/200
# 3/3 [==============================] - 0s 147ms/step - loss: 0.1589 - accuracy: 0.9573 - val_loss: 0.1902 - val_accuracy: 0.9000 - lr: 1.0000e-10
# Epoch 11/200
# 3/3 [==============================] - 1s 148ms/step - loss: 0.1640 - accuracy: 0.9658 - val_loss: 0.1895 - val_accuracy: 0.9000 - lr: 1.0000e-10
# Epoch 12/200
# 3/3 [==============================] - 1s 197ms/step - loss: 0.1656 - accuracy: 0.9658 - val_loss: 0.1888 - val_accuracy: 0.9000 - lr: 1.0000e-10
# Epoch 13/200
# 3/3 [==============================] - 1s 151ms/step - loss: 0.1728 - accuracy: 0.9573 - val_loss: 0.1882 - val_accuracy: 0.9000 - lr: 1.0000e-10
# Epoch 14/200
# 3/3 [==============================] - 0s 148ms/step - loss: 0.1700 - accuracy: 0.9573 - val_loss: 0.1876 - val_accuracy: 0.9000 - lr: 1.0000e-10
# Epoch 15/200
# 3/3 [==============================] - 1s 169ms/step - loss: 0.1782 - accuracy: 0.9658 - val_loss: 0.1869 - val_accuracy: 0.9000 - lr: 1.0000e-10
# Epoch 16/200
# 3/3 [==============================] - 0s 168ms/step - loss: 0.1547 - accuracy: 0.9573 - val_loss: 0.1865 - val_accuracy: 0.9000 - lr: 1.0000e-10
# Epoch 17/200
# 3/3 [==============================] - 0s 168ms/step - loss: 0.1598 - accuracy: 0.9658 - val_loss: 0.1862 - val_accuracy: 0.9000 - lr: 1.0000e-10
# Epoch 18/200
# 3/3 [==============================] - 1s 196ms/step - loss: 0.1647 - accuracy: 0.9658 - val_loss: 0.1857 - val_accuracy: 0.9000 - lr: 1.0000e-10
# Epoch 19/200
# 3/3 [==============================] - 0s 152ms/step - loss: 0.1618 - accuracy: 0.9573 - val_loss: 0.1851 - val_accuracy: 0.9000 - lr: 1.0000e-10
# Epoch 20/200
# 3/3 [==============================] - 0s 147ms/step - loss: 0.1669 - accuracy: 0.9573 - val_loss: 0.1845 - val_accuracy: 0.9000 - lr: 1.0000e-10
# Epoch 21/200
# 3/3 [==============================] - 0s 150ms/step - loss: 0.1580 - accuracy: 0.9658 - val_loss: 0.1842 - val_accuracy: 0.9000 - lr: 1.0000e-10
# Epoch 22/200
# 3/3 [==============================] - 1s 192ms/step - loss: 0.1669 - accuracy: 0.9658 - val_loss: 0.1837 - val_accuracy: 0.9000 - lr: 1.0000e-10
# Epoch 23/200
# 3/3 [==============================] - 1s 196ms/step - loss: 0.1708 - accuracy: 0.9658 - val_loss: 0.1834 - val_accuracy: 0.9000 - lr: 1.0000e-10
# Epoch 24/200
# 3/3 [==============================] - 1s 205ms/step - loss: 0.1725 - accuracy: 0.9573 - val_loss: 0.1828 - val_accuracy: 0.9000 - lr: 1.0000e-10
# Epoch
- val_accuracy: 0.9333 - lr: 1.0000e-15
# Epoch 184/200
# 3/3 [==============================] - 1s 218ms/step - loss: 0.1669 - accuracy: 0.9658 - val_loss: 0.1717 - val_accuracy: 0.9333 - lr: 1.0000e-15
# Epoch 185/200
# 3/3 [==============================] - 1s 231ms/step - loss: 0.1643 - accuracy: 0.9573 - val_loss: 0.1718 - val_accuracy: 0.9333 - lr: 1.0000e-15
# Epoch 186/200
# 3/3 [==============================] - 1s 211ms/step - loss: 0.1631 - accuracy: 0.9487 - val_loss: 0.1719 - val_accuracy: 0.9333 - lr: 1.0000e-15
# Epoch 187/200
# 3/3 [==============================] - 1s 227ms/step - loss: 0.1623 - accuracy: 0.9658 - val_loss: 0.1721 - val_accuracy: 0.9333 - lr: 1.0000e-15
# Epoch 188/200
# 3/3 [==============================] - 1s 212ms/step - loss: 0.1596 - accuracy: 0.9573 - val_loss: 0.1720 - val_accuracy: 0.9333 - lr: 1.0000e-15
# Epoch 189/200
# 3/3 [==============================] - 1s 172ms/step - loss: 0.1671 - accuracy: 0.9573 - val_loss: 0.1719 - val_accuracy: 0.9333 - lr: 1.0000e-15
# Epoch 190/200
# 3/3 [==============================] - 1s 187ms/step - loss: 0.1699 - accuracy: 0.9658 - val_loss: 0.1719 - val_accuracy: 0.9333 - lr: 1.0000e-15
# Epoch 191/200
# 3/3 [==============================] - 1s 205ms/step - loss: 0.1579 - accuracy: 0.9658 - val_loss: 0.1718 - val_accuracy: 0.9333 - lr: 1.0000e-15
# Epoch 192/200
# 3/3 [==============================] - 1s 216ms/step - loss: 0.1680 - accuracy: 0.9573 - val_loss: 0.1717 - val_accuracy: 0.9333 - lr: 1.0000e-15
# Epoch 193/200
# 3/3 [==============================] - 1s 182ms/step - loss: 0.1745 - accuracy: 0.9487 - val_loss: 0.1718 - val_accuracy: 0.9333 - lr: 1.0000e-16
# Epoch 194/200
# 3/3 [==============================] - 1s 234ms/step - loss: 0.1759 - accuracy: 0.9573 - val_loss: 0.1720 - val_accuracy: 0.9333 - lr: 1.0000e-16
# Epoch 195/200
# 3/3 [==============================] - 1s 181ms/step - loss: 0.1674 - accuracy: 0.9573 - val_loss: 0.1720 - val_accuracy: 0.9333 - lr: 1.0000e-16
# Epoch 196/200
# 3/3 [==============================] - 1s 176ms/step - loss: 0.1710 - accuracy: 0.9658 - val_loss: 0.1720 - val_accuracy: 0.9333 - lr: 1.0000e-16
# Epoch 197/200
# 3/3 [==============================] - 1s 185ms/step - loss: 0.1727 - accuracy: 0.9658 - val_loss: 0.1720 - val_accuracy: 0.9333 - lr: 1.0000e-16
# Epoch 198/200
# 3/3 [==============================] - 1s 177ms/step - loss: 0.1617 - accuracy: 0.9487 - val_loss: 0.1719 - val_accuracy: 0.9333 - lr: 1.0000e-16
# Epoch 199/200
# 3/3 [==============================] - 1s 172ms/step - loss: 0.1802 - accuracy: 0.9658 - val_loss: 0.1720 - val_accuracy: 0.9333 - lr: 1.0000e-16
# Epoch 200/200
# 3/3 [==============================] - 1s 175ms/step - loss: 0.1727 - accuracy: 0.9658 - val_loss: 0.1720 - val_accuracy: 0.9333 - lr: 1.0000e-16

# %%
acc = traino.history['accuracy']
val_acc = traino.history['val_accuracy']
loss = traino.history['loss']
val_loss = traino.history['val_loss']
    
epochs_range = range(1, len(acc)+1)
    #Train and validation accuracy 
plt.figure(figsize=(15, 15))
plt.subplot(2, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')
    #Train and validation loss 
plt.subplot(2, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
_, val_acc = model_o.evaluate(X_val_o, Y_val_o, verbose=0)
print('Validation accuracy: %.3f' % (val_acc))
    
    
preds = model_o.predict(X_val_o, verbose=1)

    #Compute Receiver operating characteristic (ROC)
fpr, tpr, _ = roc_curve(Y_val_o, preds)

roc_auc = auc(fpr, tpr)
   #Plot of a ROC curve
plt.figure()
lw = 2
plt.plot(fpr, tpr, color='darkorange', lw=lw, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic example')
plt.legend(loc="lower right")
plt.show()
# Out:
# Validation accuracy: 0.933
# 1/1 [==============================] - 0s 51ms/step

# %%
#CROSS-VALIDATION with ORIGINAL DATA (X_slice_o)

A = []
V_A = []
L = []
V_L = []
ROC = []

for i in range(3):
    X_train_o, X_val_o, Y_train_o, Y_val_o = train_test_split(mammo_o_4d, label, test_size = 0.168, random_state = 40)
    traino = model_o.fit(X_train_o, Y_train_o,
                            batch_size = 49,
                            epochs = 200,
                            verbose=1,
                            validation_data=(X_val_o, Y_val_o),
                            callbacks=[checkpoint,reduce_on_plateau])
    
    acc = traino.history['accuracy']
    val_acc = traino.history['val_accuracy']
    loss = traino.history['loss']
    val_loss = traino.history['val_loss']
    
    A.append(acc)
    V_A.append(val_acc)
    L.append(loss)
    V_L.append(val_loss)
    
    epochs_range = range(1, len(acc)+1)
    #Train and validation accuracy 
    plt.figure(figsize=(15, 15))
    plt.subplot(2, 2, 1)
    plt.plot(epochs_range, acc, label='Training Accuracy')
    plt.plot(epochs_range, val_acc, label='Validation Accuracy')
    plt.legend(loc='lower right')
    plt.title('Training and Validation Accuracy')
    #Train and validation loss 
    plt.subplot(2, 2, 2)
    plt.plot(epochs_range, loss, label='Training Loss')
    plt.plot(epochs_range, val_loss, label='Validation Loss')
    plt.legend(loc='upper right')
    plt.title('Training and Validation Loss')
    plt.show()
    
    _, val_acc = model_o.evaluate(X_val_o, Y_val_o, verbose=0)
    print('Validation accuracy: %.3f' % (val_acc))
    
    
    preds = model_o.predict(X_val_o, verbose=1)

    #Compute Receiver operating characteristic (ROC)
    fpr, tpr, _ = roc_curve(Y_val_o, preds)

    roc_auc = auc(fpr, tpr)
    ROC.append(roc_auc)
    #Plot of a ROC curve
    plt.figure()
    lw = 2
    plt.plot(fpr, tpr, color='darkorange', lw=lw, label='ROC curve (area = %0.2f)' % roc_auc)
    plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver operating characteristic example')
    plt.legend(loc="lower right")
    plt.show()

# %%
media = np.mean(ROC)
std = np.std(ROC)
print(media)
print(std)
